# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 파일 읽기
pay = pd.read_csv('2006_2018연령별_임금_및_근로시간.csv', encoding='cp949')
# pay1 = pd.DataFrame(pay).set_index('고용형태')
pay
# Out:
#                고용형태      연령        2006     2006.1     2006.2       2006.3  \
# 0              고용형태      연령  월임금총액 (천원)  월급여액 (천원)  초과급여 (천원)  연간특별급여 (천원)
# 1             전체근로자      전체        2069       1742        112         3923
# 2             전체근로자   29세이하        1441       1273         86         2017
# 3             전체근로자  30~39세        2251       1887        115         4367
# 4             전체근로자  40~49세        2500       2049        141         5414
# 5             전체근로자  50~59세        2357       1948        137         4907
# 6             전체근로자   60세이상        1523       1383         29         1686
# 7     전체근로자(특수형태포함)      전체        2071       1756        108         3783
# 8     전체근로자(특수형태포함)   29세이하        1445       1280         84         1977
# 9     전체근로자(특수형태포함)  30~39세        2259       1909        110         4192
# 10    전체근로자(특수형태포함)  40~49세        2484       2055        133         5147
# ...

# %%
# 임금현황
# 해당 년도의 임금(월임금총액*12 + 연간특별급여) 
# 연령별 (29세 이하, 30~39세, 40~49세, 50~59세, 60세 이상, 전체임금)

# %%
pay.dtypes
pay1 = pay

# %%
pay1['2006'][1:] = pay['2006'][1:].astype('int') * 12 + pay['2006.3'][1:].astype('int')
pay1['2007'][1:] = pay['2007'][1:].astype('int') * 12 + pay['2007.3'][1:].astype('int')
pay1['2008'][1:] = pay['2008'][1:].astype('int') * 12 + pay['2008.3'][1:].astype('int')
pay1['2009'][1:] = pay['2009'][1:].astype('int') * 12 + pay['2009.3'][1:].astype('int')
pay1['2010'][1:] = pay['2010'][1:].astype('int') * 12 + pay['2010.3'][1:].astype('int')
pay1['2011'][1:] = pay['2011'][1:].astype('int') * 12 + pay['2011.3'][1:].astype('int')
pay1['2012'][1:] = pay['2012'][1:].astype('int') * 12 + pay['2012.3'][1:].astype('int')
pay1['2013'][1:] = pay['2013'][1:].astype('int') * 12 + pay['2013.3'][1:].astype('int')
pay1['2014'][1:] = pay['2014'][1:].astype('int') * 12 + pay['2014.3'][1:].astype('int')
pay1['2015'][1:] = pay['2015'][1:].astype('int') * 12 + pay['2015.3'][1:].astype('int')
pay1['2016'][1:] = pay['2016'][1:].astype('int') * 12 + pay['2016.3'][1:].astype('int')
pay1['2017'][1:] = pay['2017'][1:].astype('int') * 12 + pay['2017.3'][1:].astype('int')
pay1['2018'][1:] = pay['2018'][1:].astype('int') * 12 + pay['2018.3'][1:].astype('int')

# %%
# df.loc
pay1 = pay1[['고용형태', '연령', '2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018']]
pay1.to_csv('연령별_임금_2006~2018', encoding='utf-8')

# %%
# 제일 윗 행 지우기
pay2 = pay1[1:]
# pay2.set_index(['연령'])
#pay2.set_index(['고용형태'],['연령'])
pay2.head(2)
# Out:
#     고용형태     연령   2006   2007   2008   2009   2010   2011   2012   2013  \
# 1  전체근로자     전체  28751  30114  31365  31125  31542  33049  34053  35346
# 2  전체근로자  29세이하  19309  20784  21510  21431  21475  22774  23370  23865
#
#     2014   2015   2016   2017   2018
# 1  36567  36775  38023  38571  40252
# 2  25223  24234  25181  25537  27262

# %%
pay3 = pay2.T
pay3.head(4)
# Out:
#          1      2       3       4       5      6              7   \
# 고용형태  전체근로자  전체근로자   전체근로자   전체근로자   전체근로자  전체근로자  전체근로자(특수형태포함)
# 연령       전체  29세이하  30~39세  40~49세  50~59세  60세이상             전체
# 2006  28751  19309   31379   35414   33191  19962          28635
# 2007  30114  20784   33193   36357   33942  20753          29975
#
#                  8              9              10  ...      21      22  \
# 고용형태  전체근로자(특수형태포함)  전체근로자(특수형태포함)  전체근로자(특수형태포함)  ...  비정규근로자  비정규근로자
# 연령            29세이하         30~39세         40~49세  ...  30~39세  40~49세
# 2006          19317          31300          34955  ...   15626   14401
# 2007          20786          33002          35922  ...   16551   15561
#
#           23      24               25               26               27  \
# 고용형태  비정규근로자  비정규근로자  비정규직근로자(특수형태포함)  비정규직근로자(특수형태포함)  비정규직근로자(특수형태포함)
# 연령    50~59세   60세이상               전체            29세이하           30~39세
# ...

# %%
pay3.shape
# Out:
# (15, 30)

# %%
pay3.index
# Out:
# Index(['고용형태', '연령', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018'],
#       dtype='object')

# %%
pay3.columns
# Out:
# RangeIndex(start=1, stop=31, step=1)

# %%
#pivot에서 자료 재구조화하기
pay2 = pay2.set_index(['고용형태', '연령'])

# %%
pay3 = pay2.T
pay3
# Out:
# 고용형태  전체근로자                                    전체근로자(특수형태포함)                \
# 연령       전체  29세이하 30~39세 40~49세 50~59세  60세이상            전체  29세이하 30~39세
# 2006  28751  19309  31379  35414  33191  19962         28635  19317  31300
# 2007  30114  20784  33193  36357  33942  20753         29975  20786  33002
# 2008  31365  21510  34491  37671  34672  21588         31175  21478  34208
# 2009  31125  21431  33993  37476  33565  20640         30881  21377  33606
# 2010  31542  21475  34767  37674  33703  20765         31276  21455  34358
# 2011  33049  22774  35861  39547  35256  21509         32675  22683  35179
# 2012  34053  23370  36938  40436  36220  22433         33685  23344  36281
# 2013  35346  23865  37796  41771  38822  23628         35193  23843  37404
# 2014  36567  25223  40619  43441  37973  23150         36321  25186  40184
# 2015  36775  24234  40067  44659  38930  24044         36529  24205  39625
# ...

# %%
pay3['2016']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2016'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-795a43d69483> in <module>
# ----> 1 pay3['2016']
#
# ...

# %%
plt.figure(figsize=(10,7))
plt.plot(pay2['년도'], pay2['관측일수'])
plt.title('서울시 연도별 황사 관측일 수 흐름', fontsize=20)

# %%
plt.figure(figsize=(10,7))
plt.plot(pay2['2016'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-215cff211ed5> in <module>
#       1 plt.figure(figsize=(10,7))
# ----> 2 plt.plot(pay2['2016'])
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# ...
